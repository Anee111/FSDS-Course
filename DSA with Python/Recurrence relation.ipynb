# %%
# 1 Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.
 2. Given a recurrence relation, solve it using the substitution method:
 a. T(n) = T(n-1) + c
 b. T(n) = 2T(n/2) + n
 c. T(n) = 2T(n/2) + c
 d. T(n) = T(n/2) + c
 3. Given a recurrence relation, solve it using the recursive tree approach:
 a. T(n) = 2T(n-1) +1
 b. T(n) = 2T(n/2) + n

# %%
#1

First, calculate 
𝑇
(
1
)
T(1): 
𝑇
(
1
)
=
3
𝑇
(
0
)
+
12
⋅
1
T(1)=3T(0)+12⋅1 
𝑇
(
1
)
=
3
⋅
5
+
12
T(1)=3⋅5+12 
𝑇
(
1
)
=
15
+
12
T(1)=15+12 
𝑇
(
1
)
=
27
T(1)=27

Next, calculate 
𝑇
(
2
)
T(2): 
𝑇
(
2
)
=
3
𝑇
(
1
)
+
12
⋅
2
T(2)=3T(1)+12⋅2 
𝑇
(
2
)
=
3
⋅
27
+
24
T(2)=3⋅27+24 
𝑇
(
2
)
=
81
+
24
T(2)=81+24 
𝑇
(
2
)
=
105
T(2)=105

Answer: 
𝑇
(
2
)
=
105
T(2)=105

# %%
# 2

a. 
𝑇
(
𝑛
)
=
𝑇
(
𝑛
−
1
)
+
𝑐
T(n)=T(n−1)+c
Solution:

Guess: 
𝑇
(
𝑛
)
=
𝑇
(
0
)
+
𝑐
𝑛
T(n)=T(0)+cn
Base Case: For 
𝑛
=
0
n=0, 
𝑇
(
0
)
=
𝑇
(
0
)
T(0)=T(0) (True)
Inductive Step: Assume 
𝑇
(
𝑘
)
=
𝑇
(
0
)
+
𝑐
𝑘
T(k)=T(0)+ck is true for 
𝑘
k. Then, 
𝑇
(
𝑘
+
1
)
=
𝑇
(
𝑘
)
+
𝑐
T(k+1)=T(k)+c Substitute the inductive hypothesis: 
𝑇
(
𝑘
+
1
)
=
(
𝑇
(
0
)
+
𝑐
𝑘
)
+
𝑐
T(k+1)=(T(0)+ck)+c 
𝑇
(
𝑘
+
1
)
=
𝑇
(
0
)
+
𝑐
(
𝑘
+
1
)
T(k+1)=T(0)+c(k+1)
So, 
𝑇
(
𝑛
)
=
𝑇
(
0
)
+
𝑐
𝑛
T(n)=T(0)+cn is a valid solution.

b. 
𝑇
(
𝑛
)
=
2
𝑇
(
𝑛
/
2
)
+
𝑛
T(n)=2T(n/2)+n
Solution:

Guess: 
𝑇
(
𝑛
)
=
𝑂
(
𝑛
log
⁡
𝑛
)
T(n)=O(nlogn)

Substitution:

Assume 
𝑇
(
𝑘
)
=
𝑘
log
⁡
𝑘
T(k)=klogk for 
𝑘
=
𝑛
/
2
k=n/2, 
𝑇
(
𝑛
)
=
2
⋅
(
𝑛
/
2
log
⁡
(
𝑛
/
2
)
)
+
𝑛
T(n)=2⋅(n/2log(n/2))+n 
𝑇
(
𝑛
)
=
𝑛
log
⁡
(
𝑛
/
2
)
+
𝑛
T(n)=nlog(n/2)+n 
𝑇
(
𝑛
)
=
𝑛
(
log
⁡
𝑛
−
log
⁡
2
)
+
𝑛
T(n)=n(logn−log2)+n 
𝑇
(
𝑛
)
=
𝑛
log
⁡
𝑛
−
𝑛
log
⁡
2
+
𝑛
T(n)=nlogn−nlog2+n
Since 
−
𝑛
log
⁡
2
+
𝑛
−nlog2+n is dominated by 
𝑛
log
⁡
𝑛
nlogn, the solution is 
𝑇
(
𝑛
)
=
𝑂
(
𝑛
log
⁡
𝑛
)
T(n)=O(nlogn).

c. 
𝑇
(
𝑛
)
=
2
𝑇
(
𝑛
/
2
)
+
𝑐
T(n)=2T(n/2)+c
Solution:

Guess: 
𝑇
(
𝑛
)
=
𝑂
(
𝑛
)
T(n)=O(n)

Substitution:

Assume 
𝑇
(
𝑛
)
=
𝑐
𝑛
T(n)=cn, 
𝑇
(
𝑛
)
=
2
⋅
(
𝑐
⋅
𝑛
/
2
)
+
𝑐
T(n)=2⋅(c⋅n/2)+c 
𝑇
(
𝑛
)
=
𝑐
𝑛
+
𝑐
T(n)=cn+c
Hence, the solution is 
𝑇
(
𝑛
)
=
𝑂
(
𝑛
)
T(n)=O(n).

d. 
𝑇
(
𝑛
)
=
𝑇
(
𝑛
/
2
)
+
𝑐
T(n)=T(n/2)+c
Solution:

Guess: 
𝑇
(
𝑛
)
=
𝑂
(
log
⁡
𝑛
)
T(n)=O(logn)

Substitution:

Assume 
𝑇
(
𝑛
)
=
𝑐
log
⁡
𝑛
T(n)=clogn, 
𝑇
(
𝑛
)
=
𝑐
log
⁡
(
𝑛
/
2
)
+
𝑐
T(n)=clog(n/2)+c 
𝑇
(
𝑛
)
=
𝑐
(
log
⁡
𝑛
−
log
⁡
2
)
+
𝑐
T(n)=c(logn−log2)+c 
𝑇
(
𝑛
)
=
𝑐
log
⁡
𝑛
−
𝑐
log
⁡
2
+
𝑐
T(n)=clogn−clog2+c
Since 
−
𝑐
log
⁡
2
+
𝑐
−clog2+c is a constant, the solution is 
𝑇
(
𝑛
)
=
𝑂
(
log
⁡
𝑛
)
T(n)=O(logn).

# %%
# 3

a. 
𝑇
(
𝑛
)
=
2
𝑇
(
𝑛
−
1
)
+
1
T(n)=2T(n−1)+1
Solution:

Construct the recursion tree:

Level 0: 
𝑇
(
𝑛
)
T(n)
Level 1: 
2
𝑇
(
𝑛
−
1
)
2T(n−1)
Level 2: 
2
⋅
2
𝑇
(
𝑛
−
2
)
=
4
𝑇
(
𝑛
−
2
)
2⋅2T(n−2)=4T(n−2)
In general, at level 
𝑖
i, we have 
2
𝑖
𝑇
(
𝑛
−
𝑖
)
2 
i
 T(n−i)
The number of levels is 
𝑛
n (until we reach 
𝑇
(
0
)
T(0)):

𝑇
(
𝑛
)
=
2
0
⋅
1
+
2
1
⋅
1
+
2
2
⋅
1
+
⋯
+
2
𝑛
⋅
1
T(n)=2 
0
 ⋅1+2 
1
 ⋅1+2 
2
 ⋅1+⋯+2 
n
 ⋅1
This is a geometric series:

𝑇
(
𝑛
)
=
2
𝑛
+
1
−
1
T(n)=2 
n+1
 −1
Answer: 
𝑇
(
𝑛
)
=
𝑂
(
2
𝑛
)
T(n)=O(2 
n
 )

b. 
𝑇
(
𝑛
)
=
2
𝑇
(
𝑛
/
2
)
+
𝑛
T(n)=2T(n/2)+n
Solution:

Construct the recursion tree:

Level 0: 
𝑇
(
𝑛
)
T(n)
Level 1: 
2
𝑇
(
𝑛
/
2
)
2T(n/2)
Level 2: 
2
⋅
2
𝑇
(
𝑛
/
4
)
=
4
𝑇
(
𝑛
/
4
)
2⋅2T(n/4)=4T(n/4)
In general, at level 
𝑖
i, we have 
2
𝑖
𝑇
(
𝑛
/
2
𝑖
)
2 
i
 T(n/2 
i
 )
The number of levels is 
log
⁡
𝑛
logn (until we reach 
𝑇
(
1
)
T(1)).
The cost at each level is:

Level 0: 
𝑛
n
Level 1: 
𝑛
n
Level 2: 
𝑛
n
Total cost is:
𝑇
(
𝑛
)
=
𝑛
log
⁡
𝑛
T(n)=nlogn
Answer: 
𝑇
(
𝑛
)
=
𝑂
(
𝑛
log
⁡
𝑛
)
T(n)=O(nlogn)
